# %%
import pandas as pd
import os

# %%
####Importing the csv files

# %%
df1 = pd.read_csv ('Sales_April_2019.csv')
print (df1)
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1          NaN                         NaN              NaN        NaN
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 18378   194090                Google Phone                1        600
# 18379   194091       AA Batteries (4-pack)                1       3.84
# 18380   194092      AAA Batteries (4-pack)                2       2.99
# 18381   194093       AA Batteries (4-pack)                1       3.84
# 18382   194094    Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# ...

# %%
os.chdir("SalesAnalysis\Sales_Data")

# %%
files= [file for file in os.listdir()]
all_months_data = pd.DataFrame()
for file in files:
    df = pd.read_csv(file)
    all_months_data = pd.concat([all_months_data,df])
all_months_data.to_csv("all_months_data.csv",index=False)

# %%
#### Read data

# %%
all_data = pd.read_csv("all_months_data.csv")
all_data.head(50)
# Out:
#    Order ID                     Product Quantity Ordered Price Each  \
# 0    176558        USB-C Charging Cable                2      11.95
# 1       NaN                         NaN              NaN        NaN
# 2    176559  Bose SoundSport Headphones                1      99.99
# 3    176560                Google Phone                1        600
# 4    176560            Wired Headphones                1      11.99
# 5    176561            Wired Headphones                1      11.99
# 6    176562        USB-C Charging Cable                1      11.95
# 7    176563  Bose SoundSport Headphones                1      99.99
# 8    176564        USB-C Charging Cable                1      11.95
# 9    176565          Macbook Pro Laptop                1       1700
# 10   176566            Wired Headphones                1      11.99
# 11   176567                Google Phone                1        600
# 12   176568    Lightning Charging Cable                1      14.95
# ...

# %% [markdown]
# # adding helpful columns

# %% [markdown]
# clean NaN

# %% [markdown]
# add a month column

# %%
all_data['month']=all_data['Order Date'].str[0:2]
all_data['month'] = all_data['month'].astype('int32')
all_data.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-106-d5cca6159202> in <module>
#       1 all_data['month']=all_data['Order Date'].str[0:2]
# ----> 2 all_data['month'] = all_data['month'].astype('int32')
#       3 all_data.head()
#
# c:\users\achref missaoui\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# c:\users\achref missaoui\appdata\local\programs\python\python39\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
# ...

# %% [markdown]
# adding a profit column

# %%
try:
    all_data['profit']=float(all_data['Quantity Ordered']) * fload(all_data['Price Each'])
except TypeError:
    print('error')
all_data.head()
# Out:
# error
#       Order ID                   Product Quantity Ordered Price Each  \
# 73891   147268          Wired Headphones                1      11.99
# 74701   148041      USB-C Charging Cable                1      11.95
# 76054   149343  Apple Airpods Headphones                1        150
# 76708   149964    AAA Batteries (4-pack)                1       2.99
# 76061   149350      USB-C Charging Cable                2      11.95
#
#            Order Date                        Purchase Address month
# 73891  01/01/19 03:07      9 Lake St, New York City, NY 10001    01
# 74701  01/01/19 03:40  760 Church St, San Francisco, CA 94016    01
# 76054  01/01/19 04:56     735 5th St, New York City, NY 10001    01
# 76708  01/01/19 05:53         75 Jackson St, Dallas, TX 75001    01
# 76061  01/01/19 06:03           943 2nd St, Atlanta, GA 30301    01

# %%
# Whats was the best month for sales?

# %%
all_data= all_data.sort_values(by="Order Date")
all_data.head()
print(all_data.loc[:,["month","Quantity Ordered","Price Each"]])
# Out:
#        month Quantity Ordered Price Each
# 73891     01                1      11.99
# 74701     01                1      11.95
# 76054     01                1        150
# 76708     01                1       2.99
# 76061     01                2      11.95
# ...      ...              ...        ...
# 185176   NaN              NaN        NaN
# 185438   NaN              NaN        NaN
# 186042   NaN              NaN        NaN
# 186548   NaN              NaN        NaN
# 186826   NaN              NaN        NaN
#
# [186850 rows x 3 columns]
